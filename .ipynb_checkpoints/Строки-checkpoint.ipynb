# %% [markdown]
# # Строки

# %% [markdown]
# ## Регистр

# %%
'aba lovelace'.title()
# Out:
# 'Aba Lovelace'

# %%
'aba lovelace'.upper()
# Out:
# 'ABA LOVELACE'

# %%
'ABA LOVELACE'.lower()
# Out:
# 'aba lovelace'

# %% [markdown]
# ## Конкатенация

# %%
'Aba'+'Lovelace'

# %%
a='Aba'
l='Lovelace'
a+' '+l
# Out:
# 'Aba Lovelace'

# %% [markdown]
# ## Табуляция и разрыв строк

# %%
p='Python'
js='JavaScript'
p+js

# %%
p+'.\n'+js

# %%
'sdsdsd \n dsds d'
