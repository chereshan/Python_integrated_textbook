# %% [markdown]
# # ``functools``

# %%
from functools import partial
x=int('1101', base=2)
print(x)
int_2=partial(int, base=2)
x=int_2('1101')
print(x)
# Out:
# 13
# 13

# %%
from functools import partial
import operator as op

x=[]
x=int('1101', base=2)
print(x)
int_2=partial(int, base=2)
x=int_2('1101')
print(x)
